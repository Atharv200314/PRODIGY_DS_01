# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('population_by_age_group.csv')

# %%
df
# Out:
#                Country     Total      65+  25-64 years  15-24 years  \
# 0          Afghanistan  40099460   964016     12995277      8727160
# 1              Albania   2854710   463442      1527360       399113
# 2              Algeria  44177964  2731079     21871300      6007614
# 3       American Samoa     45056     3088        22433         7141
# 4              Andorra     79057    11499        48651         8570
# ..                 ...       ...      ...          ...          ...
# 230  Wallis and Futuna     11654     1521         5767         1652
# 231     Western Sahara    565590    31718       314200        80572
# 232              Yemen  32981644   886890     12210659      6733620
# 233             Zambia  19473132   338628      6734346      3975624
# 234           Zimbabwe  15993525   537915      5572892      3342436
#
#      5-14 years  0-4 years
# 0      10922454    6490554
# 1        323402     141393
# 2       8697129    4870841
# 3          8365       4029
# ...

# %%
df = df.drop(index=[row for row in df.index if 10000000 > df.loc[row, 'Total']])

# %%
df
# Out:
#          Country     Total      65+  25-64 years  15-24 years  5-14 years  \
# 0    Afghanistan  40099460   964016     12995277      8727160    10922454
# 2        Algeria  44177964  2731079     21871300      6007614     8697129
# 5         Angola  34503776   895191     11501196      6518893     9605090
# 8      Argentina  45276788  5352580     22383468      6965561     7242438
# 11     Australia  25921094  4294906     13679232      3184388     3225094
# ..           ...       ...      ...          ...          ...         ...
# 228    Venezuela  28199862  2351346     13232072      4672340     5548172
# 229      Vietnam  97468024  8531506     53125464     13836744    14606156
# 232        Yemen  32981644   886890     12210659      6733620     8436417
# 233       Zambia  19473132   338628      6734346      3975624     5351636
# 234     Zimbabwe  15993525   537915      5572892      3342436     4240570
#
#      0-4 years
# 0      6490554
# 2      4870841
# 5      5983405
# ...

# %%
sns.pairplot(df)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df = df.drop(index=[row for row in df.index if 100000000 > df.loc[row, 'Total']])

# %%
df
# Out:
#            Country       Total        65+  25-64 years  15-24 years  \
# 16      Bangladesh   169356240    9868579     81719304     32968586
# 28          Brazil   214326220   20534732    116867260     32900180
# 42           China  1425893500  187501470    825714200    160749910
# 60           Egypt   109262184    5216774     49308590     18624606
# 66        Ethiopia   120283020    3774984     43125450     25316286
# 95           India  1407563900   95749030    695659970    254585650
# 96       Indonesia   273753180   18559456    141328830     44122208
# 104          Japan   124612530   37118444     61184310     11637932
# 134         Mexico   126705140   10305739     63310524     21471972
# 152        Nigeria   213401330    6362815     72930210     41735326
# 159       Pakistan   231402110    9768444     89368240     46785260
# 166    Philippines   113880340    6065460     51870776     21054832
# 173         Russia   145102750   22626482     82482720     14281916
# ...

# %%
plt.figure(figsize=(14,4))
plt.hist(df['Total'])
# Out:
# (array([10.,  2.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([1.09262184e+08, 2.40925316e+08, 3.72588447e+08, 5.04251579e+08,
#         6.35914710e+08, 7.67577842e+08, 8.99240974e+08, 1.03090411e+09,
#         1.16256724e+09, 1.29423037e+09, 1.42589350e+09]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(14,4))
plt.scatter(df['Country'],df['Total'])

# %%
plt.figure(figsize=(14,4))
plt.bar(df['Country'],df['Total'])
# Out:
# <BarContainer object of 14 artists>

# %%
df.boxplot(['Total'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,4))
plt.plot(df['Country'],df['Total'])

# %%
plt.figure(figsize=(10,4))
sns.pairplot(df)
